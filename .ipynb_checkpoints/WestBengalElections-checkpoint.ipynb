# %%
import tweepy
import webbrowser
import time
import pandas as pd
import math
import json

# %%
consumer_key = '4VANzSEBgOaGefu8GIHVCKY8U'
consumer_secret = 'iIwXQJEqzlAAuOBl4toy05ngf94hu6HpqM96CbuCqgxT8c7mJy'

# %%
callback_url = 'oob'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_url)

# %%
redirect_url = auth.get_authorization_url()
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=BFuH2QAAAAABOqGjAAABeRvpdj0

# %%
webbrowser.open(redirect_url)
# Out:
# True

# %%
user_pin_input = input('Enter pin')
# Out:
# Enter pin7878889

# %%
auth.get_access_token(user_pin_input)
# Out:
# ('1380915825268301830-XhRGG6DsXtRtwqW4xDvhuHJNlwovYF',
#  'malyBIy1wetuhKD8SaztDD8E49LBeqNdW4JCLCUKBX3Zv')

# %%
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
F_NAME = 'retweet_data.json'
f_out = open(F_NAME, 'w')

# %%
def extract_tweets_as_df(status):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    
    #for status in timeline_list:
    status_dict = dict(vars(status))
    hashtag = vars(status)['entities']['hashtags']
    if(len(hashtag) == 0 ):
        hashtag_val = None 
    else:
        hashtag_val = []
        for i in range(len(hashtag)):
            hashtag_val.append(hashtag[i]['text'])  
    keys = vars(status).keys()
    single_tweet = {"user": status.user.screen_name, "author":status.author.screen_name, "hashtags": hashtag_val}
    for k in keys:
        try:
            v_type = type(status_dict[k])
        except:
            v_type = None

        if v_type != None:
            if v_type in allowed_types:
                single_tweet[k] = status_dict[k]
                columns.add(k)

    tweets_data.append(single_tweet)

    header_cols = list(columns)
    header_cols.append('user')
    header_cols.append('author')
    header_cols.append('hashtags')
    df = pd.DataFrame(tweets_data, columns = header_cols)
    return df

# %%
user_list = ['@BJP4Bengal', '@DilipGhoshBJP', '@SuvenduWB', '@AITCofficial', '@MamataOfficial', '@cpimspeak', '@SitaramYechury', '@INCWestBengal', '@aimim_national', '@derekobrienmp', '@DidiKeBolo', '@MahuaMoitra', '@tathagata2', '@Sujan_Speak']

# %%
i=0
for status in tweepy.Cursor(api.user_timeline, screen_name= user_list[0], tweet_mode="extended").items(500):
    print(user_list[0])
    #for retweet network
    tweet = status._json
    if tweet.get('retweeted_status'):
        #print("Yes")
        json.dump(tweet, f_out)
        f_out.write('\n')
    # ------------------    
    if(i==0):    
        df = extract_tweets_as_df(status)
    else:
        df_new = extract_tweets_as_df(status)
        df = df.append(df_new, ignore_index=True)
    i+=1

for user in user_list[1:]:
    print(user)
    for status in tweepy.Cursor(api.user_timeline, screen_name= user, tweet_mode="extended").items(500):
        #for retweet network
        tweet = status._json
        if tweet.get('retweeted_status'):
            json.dump(tweet, f_out)
            f_out.write('\n')
        # ------------------ 
        df_new = extract_tweets_as_df(status)
        df = df.append(df_new, ignore_index=True)
# Out:
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @BJP4Bengal
# @DilipGhoshBJP
# @SuvenduWB
# @AITCofficial
# @MamataOfficial
# @cpimspeak
# @SitaramYechury
# @INCWestBengal
# @aimim_national
# @derekobrienmp
# @DidiKeBolo
# @MahuaMoitra
# @tathagata2
# @Sujan_Speak

# %%
f_out.close()
# save df
filename = 'tweet_dataset.csv'
df.to_csv(filename)

# %%
#['WestBengalElections2021', 'ElectionCommissionOfIndia', 'TMC', 'BJP', 'INC', 'CPI', 'CPIM', 'AIMIM']
def extract_hashtag_from_string(hashtags):
    tag_string = hashtags[1:len(hashtags)-1]
    hashtag_list = tag_string.split(", ")
    final_hashtag_list = []
    for hashtag in hashtag_list:
        hashtag = hashtag[1:len(hashtag)-1]
        final_hashtag_list.append(hashtag)
    return final_hashtag_list

# %%
filename = './tweet_dataset.csv'
df1 = pd.read_csv(filename)
hashtag_list = []

for hashtags in df1['hashtags']:
    if(type(hashtags) != float): #to avoid nan
        #print(hashtags)
        hashtags = extract_hashtag_from_string(hashtags)
        hashtag_list.extend(hashtags)

# %%
hashtag_freq = {}
for hashtag in hashtag_list:
    #print(hashtags)
    #removing hashtag about 'USPresidentialElections2020' tweets done by @LSElections2024 and tweets for Bihar and Delhi elections
    if(hashtag == 'RJD' or hashtag == 'LJP' or hashtag == 'RLSP' or hashtag.find('TamilNadu') != -1 or hashtag.find('Bihar') != -1 or hashtag.find('US') != -1 or hashtag.find('Delhi') != -1 or hashtag == 'बिहारविधानसभाचुनाव' or hashtag == 'AAP' or hashtag == 'बिहार_विधानसभा_निर्वाचन_प्रथम_चरण'):
        continue
    if(hashtag not in hashtag_freq.keys()):
        hashtag_freq[hashtag]=1
    else:
        hashtag_freq[hashtag]+=1
                
hashtag_freq = dict(sorted(hashtag_freq.items(), key=lambda item: item[1], reverse=True))  
print(hashtag_freq)
# Out:
# {'MegaPublicRally': 75, 'TMC200Paar': 73, 'LokhhoSonarBangla': 71, 'Vote4AsolPoriborton': 67, 'VoteForTMC': 66, 'Nandigram': 63, 'ModiMadeDisaster': 50, 'COVID19': 48, 'EbarBJPEbarSonarBangla': 47, 'BanglaAcheModiJirSathe': 47, 'BanglaChayBJPKe': 46, 'MegaRoadShow': 46, 'EiBaarBJPSarkar': 41, 'NoVoteToBJP': 34, 'EbarBJP': 31, 'WestBengalElections2021': 29, 'BengalElection2021': 29, 'Bengal': 28, 'BanglaNijerMeyekeiChay': 28, 'KisanMazdoorPadyatra': 28, 'SonarBanglaSonkolpoPotro': 26, 'Vote4Left': 25, 'LDFforSure': 25, 'BohiragotoChaiNa': 24, 'Vote4SanjuktaMorcha': 24, 'ModiHataoDeshBachao': 22, 'EbarBJPSorkar': 19, 'MegaPublicMeeting': 19, 'GarjeNaari': 19, 'Didir10Ongikar': 18, 'PeoplesBrigade': 18, 'COVIDEmergency2021': 18, 'BanglarManushBJPErSathe': 17, 'MamataBanerjee': 17, 'Kolkata': 17, 'FighterDidi': 16, 'SonarBangla': 15, 'BengalElections2021': 15, 'WBWelcomesRahulGandhi': 15, 'Bangla': 14, 'SanjuktaMorcha': 14, 'PMDoesNotCare': 13, 'KhelaHobe': 13, 'IndiaAgainstLPGLoot': 13, 'PublicMeeting': 12, 'PoribortonYatra': 12, 'ResignModi': 12, 'BengalNeedsLeft': 12, 'BengalForFarmers': 12, 'BJP4SonarBangla': 11, 'Hooghly': 11, 'Parliament': 11, 'KolkataCovidCare': 11, 'PishiTomarKhelaShesh': 10, 'PoliticalTerrorism': 10, 'Covid19': 10, 'BharatBandh': 10, 'WestBengal': 9, 'MahaPadayatra': 9, 'आज_भारत_बंद_है': 9, 'Apnar_Vote_Congress_Jot': 9, 'AarNoiAnnay': 8, 'BJP200PlusInBengal': 8, 'BanglayBJP': 8, 'JitcheBJPJitcheBangla': 8, 'LokkhoSonarBangla': 8, 'Haldia': 8, 'BengalFightsCorona': 8, 'TaphoshiliBirodhiBJP': 8, 'BlackDayForDemocracy': 8, 'GoWB': 8, 'vaccine': 8, 'AIMIM': 8, 'Asansol': 7, 'নন্দীগ্রাম': 7, 'SonaChura': 7, 'InternationalWomensDay': 7, 'LeftAlternative': 7, 'COVID19India': 7, 'FarmersProtest': 7, 'WeCantBreathe': 7, 'Vote4SonarBangla': 6, 'RamNavami': 6, 'WestBengalElections': 6, 'BJP': 6, 'TMC': 6, 'Malda': 6, 'আসল_পরিবর্তন': 6, 'সোনার_বাংলা': 6, 'MahaJogdanMela': 6, 'MahaShivaRatri': 6, 'CashForVote': 6, 'DidirSatheNandigram': 6, 'IWD2021': 6, 'DuareSarkar': 6, 'Banglay_Ebar_Congress_Kei_Dorkar': 6, 'CovidIndia': 6, 'vaccination': 6, 'Covid': 6, 'FactCheck': 6, 'DidiKeBolo': 6, 'GetWellSoonPM': 6, '26NovGeneralStrike': 6, 'EbaarBJPSorkar': 5, 'Vote4BJP': 5, 'Panskura': 5, 'Kanthi': 5, 'Jhargram': 5, 'PoribortanYatra': 5, 'Chuchura': 5, 'AbhishekBanerjee': 5, 'Banglar_Sankalpa_Congress_Bikalpa': 5, 'BJPKorbe200Paar': 4, 'KhelaSesh': 4, 'JaiShriRam': 4, 'Mecheda': 4, 'Murshidabad': 4, 'Kultali': 4, 'COVID': 4, 'TMCSweepsPhase1': 4, 'BengalRejectsGujaratiManifesto': 4, 'DeshNayakDibas': 4, 'VaccineForAll': 4, 'FarmersProstests': 4, 'DishaRavi': 4, 'Elections2021': 4, 'Oxygen': 4, 'dekho_amitshah': 4, 'CovidHelp': 4, 'COVIDEmergency': 4, 'ModiOxygenDo': 4, 'জোটেভোট': 4, 'IndiaFightsCorona': 3, 'ModirSatheBangla': 3, 'BanglayEbarBJPAsche': 3, 'HanumanJayanti': 3, 'MahavirJayanti': 3, 'Video': 3, 'PoilaBoishakh': 3, 'EbarHobeAsolPoriborton': 3, 'PishiHarcheBanglaJitche': 3, 'BanglayEbarAsolPoriborton': 3, 'WestBengalPolls': 3, 'ModirSatheiAsolPoriborton': 3, 'Maniktala': 3, 'Shyampukur': 3, 'Burwan': 3, 'Khargram': 3, 'Kandi': 3, 'Jorasanko': 3, 'Chanchal': 3, 'Ratua': 3, 'Manikchak': 3, 'Ranaghat': 3, 'Nadia': 3, 'Howrah': 3, 'WELCOME': 3, 'এগরা': 3, 'Egra': 3, 'Bagcha': 3, 'Moyna': 3, 'Nimtouri': 3, 'MartyrsDay': 3, 'শিবরাত্রি': 3, 'Tamluk': 3, 'Dankuni': 3, 'ISKCON': 3, 'পরিবর্তন_যাত্রা': 3, 'Barrackpur': 3, 'UttarPradesh': 3, 'AskAB': 3, 'NoToBJP': 3, 'KrishakDibas': 3, '1KotirDuareSarkar': 3, 'TeamIndia': 3, 'AmbedkarJayanti': 3, 'WestBengalElection2021': 3, 'Joy': 3, 'FarmLaws': 3, 'IndiaNeedsOxygen': 3, 'indianeedsoxygen': 3, 'DeshKiDharohar': 3, 'BJPHoardingRemdesivir': 3, 'MissionZilaPanchayat': 3, 'AIMIMUttarPradesh': 3, 'ABPExclusive': 3, 'RafaleScam': 3, 'TrendingTonight': 3, 'VIDEO': 3, 'Didi': 3, 'ModiShah': 3, 'WestBengalAssemblyElection2021': 3, 'BuddhadebBhattacharya': 3, 'MazdoorKisanStrike': 3, 'sonarbanglasonkolpopotro': 2, 'Vote4BJPSonarBangla': 2, 'Vote4BJP4SonarBangla': 2, 'sonarbanglagorbeb ...

# %%
import matplotlib.pyplot as plt

# %%
vals = [key for key in hashtag_freq.keys()]
#print(in_vals)
hist = [hashtag_freq[key] for key in hashtag_freq.keys()]

#for more clear plots
final_vals = []
final_hist = []
for key in hashtag_freq.keys():
    if(hashtag_freq[key] > 3):
        final_vals.append(key)
        final_hist.append(hashtag_freq[key])

# %%
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['Source Han Sans TW',
                                   'sans-serif',
                                   'Arial Unicode MS'  # fc-list :lang=hi family
                                   ]
# Figure Size
fig, ax = plt.subplots(figsize =(50, 50))
 
# Horizontal Bar Plot
#ax.barh(vals, hist)
ax.barh(final_vals, final_hist)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
    
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 15)
ax.yaxis.set_tick_params(pad = 20)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 8, fontweight ='bold',
             color ='grey')

# Add Plot Title
ax.set_title("Frequency distribution of hastags")
 
# Show Plot
plt.savefig('./hashtag_frequency_distribution_final.pdf')

# %%
#print top-k hashtags 
def top_k_hashtags(hashtag_freq, k):
    count = 0
    print('Top - ', k, ' hashtags are : ')
    for keys in hashtag_freq.keys():
        print(keys, " : ", hashtag_freq[keys])
        if(count == 20):
            break
        count+=1

top_k_hashtags(hashtag_freq, 20)
# Out:
# Top -  20  hashtags are :
# MegaPublicRally  :  75
# TMC200Paar  :  73
# LokhhoSonarBangla  :  71
# Vote4AsolPoriborton  :  67
# VoteForTMC  :  66
# Nandigram  :  63
# ModiMadeDisaster  :  50
# COVID19  :  48
# EbarBJPEbarSonarBangla  :  47
# BanglaAcheModiJirSathe  :  47
# BanglaChayBJPKe  :  46
# MegaRoadShow  :  46
# EiBaarBJPSarkar  :  41
# NoVoteToBJP  :  34
# EbarBJP  :  31
# WestBengalElections2021  :  29
# BengalElection2021  :  29
# Bengal  :  28
# BanglaNijerMeyekeiChay  :  28
# KisanMazdoorPadyatra  :  28
# SonarBanglaSonkolpoPotro  :  26
